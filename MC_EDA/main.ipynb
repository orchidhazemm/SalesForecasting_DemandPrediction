# %%
from preproccessing import *

# %%
df = load_data("data/depi.csv")
# Out:
# /Users/ziadghanem/Desktop/Sales Forcasting/DEPI_Graduation_project/MC_EDA/preproccessing.py:25: DtypeWarning: Columns (4,17,18,19,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
investegating_data(df)
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84287 entries, 0 to 84286
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         84286 non-null  object
#  1   Financial Status             26555 non-null  object
#  2   Paid at                      16118 non-null  object
#  3   Fulfillment Status           26555 non-null  object
#  4   Fulfilled at                 14829 non-null  object
#  5   Currency                     26555 non-null  object
#  6   Subtotal                     26555 non-null  float64
#  7   Shipping                     26555 non-null  float64
#  8   Taxes                        26555 non-null  float64
#  9   Total                        26555 non-null  float64
#  10  Discount Amount              26555 non-null  float64
#  11  Shipping Method              25336 non-null  object
# ...

# %%
df = handle_unneded_columns(df)
# Out:
# Unneeded columns dropped.

# %%
df = handle_missing_columns(df)
